# %% [markdown]
# APPLICATION B

# %%
from applications.b_queries import main

# %%
main()
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (a) { ... }} {position: line: 3, column: 5, offset: 26} for query: '\n    MATCH (a:Author)\n    CALL {\n       WITH a\n       MATCH (a)<-[:WRITTEN_BY]-(p:Paper)\n       OPTIONAL MATCH (p)<-[:CITED_BY]-(cp:Paper)\n       WITH p, count(cp) as citations\n       ORDER BY citations DESC\n       RETURN collect(citations) as sortedCitations\n    }\n    UNWIND range(0, size(sortedCitations)-1) as idx\n    WITH a, sortedCitations, idx, sortedCitations[idx] as currentCitation\n    WHERE currentCitation >= idx + 1\n    RETURN a.name as Author, max(idx + 1) as hIndex\n    '
# Query 1: Top 3 most cited papers for each Journal
#
# Journal: Acta Cirurgica Brasileira
# ...
